# %% [markdown]
# # Import the required Libraries

# %%
import pandas as pd

# %% [markdown]
# # Load the dataset

# %%
dataset = pd.read_excel("District_Rainfall_Normal_0.xls")

# %%
print(dataset)
# Out:
#                         STATE/UT        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
print(type(dataset))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # First 5 records of the dataset

# %%
dataset.head()
# Out:
#                       STATE/UT       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  JAN+FEB  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#      MAM    JJAS    OND
# 0  540.7  1207.2  892.1
# 1  483.5  1757.2  705.3
# ...

# %% [markdown]
# # Last 5 records of the dataset

# %%
dataset.tail()
# Out:
#         STATE/UT        DISTRICT   JAN   FEB   MAR    APR    MAY    JUN  \
# 636       KERALA          IDUKKI  13.4  22.1  43.6  150.4  232.6  651.6
# 637       KERALA        KASARGOD   2.3   1.0   8.4   46.9  217.6  999.6
# 638       KERALA  PATHANAMTHITTA  19.8  45.2  73.9  184.9  294.7  556.9
# 639       KERALA         WAYANAD   4.8   8.3  17.5   83.3  174.6  698.1
# 640  LAKSHADWEEP     LAKSHADWEEP  20.8  14.7  11.8   48.9  171.7  330.2
#
#         JUL    AUG    SEP    OCT    NOV   DEC  ANNUAL  JAN+FEB    MAM    JJAS  \
# 636   788.9  527.3  308.4  343.2  172.9  48.1  3302.5     35.5  426.6  2276.2
# 637  1108.5  636.3  263.1  234.9   84.6  18.4  3621.6      3.3  272.9  3007.5
# 638   539.9  352.7  266.2  359.4  213.5  51.3  2958.4     65.0  553.5  1715.7
# 639  1110.4  592.9  230.7  213.1   93.6  25.8  3253.1     13.1  275.4  2632.1
# 640   287.7  217.5  163.1  157.1  117.7  58.8  1600.0     35.5  232.4   998.5
#
#        OND
# 636  564.2
# 637  337.9
# 638  624.2
# 639  332.5
# ...

# %% [markdown]
# # Shape of the dataset - 641 = rows and 19 = columns

# %%
dataset.shape
# Out:
# (641, 19)

# %% [markdown]
# # Access the columns of the dataset

# %%
dataset.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'JAN+FEB', 'MAM', 'JJAS',
#        'OND'],
#       dtype='object')

# %% [markdown]
# # Convert the columns of the dataset into a list

# %%
dataset_columns = dataset.columns.tolist()
print(dataset_columns)
print(type(dataset_columns))
# Out:
# ['STATE/UT', 'DISTRICT', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'JAN+FEB', 'MAM', 'JJAS', 'OND']
# <class 'list'>

# %% [markdown]
# # Summary of the dataset using describe function

# %%
dataset.describe()
# Out:
#               JAN         FEB         MAR         APR         MAY  \
# count  641.000000  641.000000  641.000000  641.000000  641.000000
# mean    18.355070   20.984399   30.034789   45.543214   81.535101
# std     21.082806   27.729596   45.451082   71.556279  111.960390
# min      0.000000    0.000000    0.000000    0.000000    0.900000
# 25%      6.900000    7.000000    7.000000    5.000000   12.100000
# 50%     13.300000   12.300000   12.700000   15.100000   33.900000
# 75%     19.200000   24.100000   33.200000   48.300000   91.900000
# max    144.500000  229.600000  367.900000  554.400000  733.700000
#
#                JUN          JUL          AUG         SEP         OCT  \
# count   641.000000   641.000000   641.000000  641.000000  641.000000
# mean    196.007332   326.033697   291.152262  194.609048   90.446334
# std     196.556284   221.364643   152.647325   99.830540   74.990685
# min       3.800000    11.600000    14.100000    8.600000    3.100000
# ...

# %% [markdown]
# # Maximum value from each of the column

# %%
dataset.max()
# Out:
# STATE/UT    WEST BENGAL
# DISTRICT      ZUNHEBOTO
# JAN               144.5
# FEB               229.6
# MAR               367.9
# APR               554.4
# MAY               733.7
# JUN              1476.2
# JUL              1820.9
# AUG              1522.1
# SEP               826.3
# OCT               517.7
# NOV               475.1
# DEC               297.7
# ANNUAL           7229.3
# JAN+FEB           335.3
# MAM              1256.5
# JJAS               5228
# OND              1048.5
# dtype: object

# %%
dataset['JAN'].max()
# Out:
# 144.5

# %% [markdown]
# # How much average rainfall happens in January?

# %%
# use mean function
dataset['JAN'].mean()
# Out:
# 18.355070202808125

# %% [markdown]
# # which record is having maximum rainfall?

# %%
dataset['JAN'].argmax()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# 369

# %%
dataset['JAN'].iloc[369]
# Out:
# 144.5

# %%
dataset.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'JAN+FEB', 'MAM', 'JJAS',
#        'OND'],
#       dtype='object')

# %%
dataset['STATE/UT'].value_counts()
# Out:
# UTTAR PRADESH                  71
# MADHYA PRADESH                 50
# BIHAR                          38
# MAHARASHTRA                    35
# RAJASTHAN                      33
# TAMIL NADU                     32
# KARNATAKA                      30
# ORISSA                         30
# ASSAM                          27
# GUJARAT                        26
# JHARKHAND                      24
# ANDHRA PRADESH                 23
# JAMMU AND KASHMIR              22
# HARYANA                        21
# PUNJAB                         20
# WEST BENGAL                    19
# CHATISGARH                     18
# ARUNACHAL PRADESH              16
# KERALA                         14
# UTTARANCHAL                    13
# HIMACHAL                       12
# NAGALAND                       11
# MANIPUR                         9
# DELHI                           9
# MIZORAM                         9
# MEGHALAYA                       7
# PONDICHERRY                     4
# ...

# %% [markdown]
# # Accessing the values

# %%
dataset.iloc[[dataset['JUL'].argmax()]]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
#    STATE/UT    DISTRICT   JAN    FEB    MAR    APR    MAY     JUN     JUL  \
# 55  MANIPUR  TAMENGLONG  48.5  229.6  224.5  431.5  539.9  1158.7  1820.9
#
#        AUG    SEP    OCT    NOV  DEC  ANNUAL  JAN+FEB     MAM    JJAS    OND
# 55  1522.1  726.3  376.1  144.0  7.2  7229.3    278.1  1195.9  5228.0  527.3

# %%
dataset.iloc[55]
# Out:
# STATE/UT       MANIPUR
# DISTRICT    TAMENGLONG
# JAN               48.5
# FEB              229.6
# MAR              224.5
# APR              431.5
# MAY              539.9
# JUN             1158.7
# JUL             1820.9
# AUG             1522.1
# SEP              726.3
# OCT              376.1
# NOV                144
# DEC                7.2
# ANNUAL          7229.3
# JAN+FEB          278.1
# MAM             1195.9
# JJAS              5228
# OND              527.3
# Name: 55, dtype: object

# %%
dataset.iloc[[dataset['JUL'].argmax()]]['AUG']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# 55    1522.1
# Name: AUG, dtype: float64

# %% [markdown]
# # Slicing the dataframe

# %%
sorted_dataset_jan = dataset.sort_values('JAN')
print(sorted_dataset_jan)
# Out:
#               STATE/UT       DISTRICT    JAN    FEB    MAR    APR    MAY  \
# 463            GUJARAT          SURAT    0.0    0.1    0.9    0.1    5.4
# 470            GUJARAT      TAPI(SRT)    0.0    0.0    0.8    0.1    8.1
# 484        MAHARASHTRA      RATNAGIRI    0.1    0.0    0.1    3.5   31.7
# 483        MAHARASHTRA         RAIGAD    0.2    0.2    0.1    1.8   20.3
# 477            GUJARAT  SURENDRANAGAR    0.2    0.0    0.1    0.3    4.7
# ..                 ...            ...    ...    ...    ...    ...    ...
# 367  JAMMU AND KASHMIR        KISTWAR  119.4  161.8  213.5  127.5  100.4
# 337           HIMACHAL         CHAMBA  126.2  112.8  120.3   51.2   53.4
# 341           HIMACHAL  LAHUL & SPITI  132.8  137.1  176.6  108.9   91.7
# 360  JAMMU AND KASHMIR         POONCH  138.9  124.2  158.5   99.0   69.6
# 369  JAMMU AND KASHMIR    RAMBAN(DDA)  144.5  190.8  211.6  112.9   85.0
#
#        JUN     JUL    AUG    SEP    OCT   NOV   DEC  ANNUAL  JAN+FEB    MAM  \
# ...

# %%
dataset_grouped = dataset.groupby('DISTRICT')
print(dataset_grouped.get_group('SURAT'))
# Out:
#     STATE/UT DISTRICT  JAN  FEB  MAR  APR  MAY    JUN    JUL    AUG    SEP  \
# 463  GUJARAT    SURAT  0.0  0.1  0.9  0.1  5.4  223.4  495.7  326.6  207.9
#
#       OCT   NOV  DEC  ANNUAL  JAN+FEB  MAM    JJAS   OND
# 463  31.7  11.5  1.4  1304.7      0.1  6.4  1253.6  44.6

# %% [markdown]
# # Filters

# %%
annualrainfall6000 = dataset[dataset['ANNUAL']>6000]
print(annualrainfall6000)
# Out:
#      STATE/UT       DISTRICT   JAN    FEB    MAR    APR    MAY     JUN  \
# 46  MEGHALAYA  EAST KHASI HI  15.4   24.1  129.7  312.5  733.7  1476.2
# 47  MEGHALAYA  JAINTIA HILLS  33.8   44.1  115.1  282.3  598.8  1316.1
# 55    MANIPUR     TAMENGLONG  48.5  229.6  224.5  431.5  539.9  1158.7
#
#        JUL     AUG    SEP    OCT    NOV   DEC  ANNUAL  JAN+FEB     MAM  \
# 46  1518.4  1019.4  607.8  277.9   40.3  10.7  6166.1     39.5  1175.9
# 47  1591.3   933.8  826.3  517.7  110.9   9.7  6379.9     77.9   996.2
# 55  1820.9  1522.1  726.3  376.1  144.0   7.2  7229.3    278.1  1195.9
#
#       JJAS    OND
# 46  4621.8  328.9
# 47  4667.5  638.3
# 55  5228.0  527.3

# %%
rainfallbetween1000to5000 = dataset[(dataset['ANNUAL']>1000) & (dataset['ANNUAL']<5000)]
rainfallbetween1000to5000
# Out:
#                         STATE/UT        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %% [markdown]
# # Iterate thourgh the values

# %%
for col in dataset[['DISTRICT']]:
    tmpdata = dataset[col]
    print(col)
    print(tmpdata.values)
# Out:
# DISTRICT
# ['NICOBAR' 'SOUTH ANDAMAN' 'N & M ANDAMAN' 'LOHIT' 'EAST SIANG'
#  'SUBANSIRI F.D' 'TIRAP' 'ANJAW (LOHIT)' 'LOWER DIBANG' 'CHANGLANG'
#  'PAPUM PARE' 'LOW SUBANSIRI' 'UPPER SIANG' 'WEST SIANG' 'DIBANG VALLEY'
#  'WEST KAMENG' 'EAST KAMENG' 'TAWANG(W KAME' 'KURUNG KUMEY' 'CACHAR'
#  'DARRANG' 'GOALPARA' 'KAMRUP' 'LAKHIMPUR' 'NORTH CACHAR' 'NAGAON'
#  'SIVASAGAR' 'BARPETA' 'DHUBRI' 'DIBRUGARH' 'JORHAT' 'KARIMGANJ'
#  'KOKRAJHAR' 'SHONITPUR' 'GOLAGHAT' 'TINSUKIA' 'HAILAKANDI'
#  'DHEMAJI(LAKHI' 'KARBI ANGLONG' 'UDALGURI(DARA' 'KAMRUP METROP'
#  'CHIRANG(BONGAI' 'BAKSA BARPETA' 'BONGAIGAON' 'MORIGAON' 'NALBARI'
#  'EAST KHASI HI' 'JAINTIA HILLS' 'EAST GARO HIL' 'RI-BHOI' 'SOUTH GARO HI'
#  'W KHASI HILL' 'WEST GARO HIL' 'IMPHAL EAST' 'SENAPATI' 'TAMENGLONG'
#  'CHANDEL' 'UKHRUL' 'THOUBAL' 'BISHNUPUR' 'IMPHAL WEST' 'CHURACHANDPUR'
#  'AIZAWL' 'CHAMPHAI' 'KOLASIB' 'LUNGLEI' 'CHHIMTUIPUI' 'LAWNGTLAI' 'MAMIT'
# ...

# %%
for index, row in dataset.loc[:,['DISTRICT']].iterrows():
    print(index)
    print(row)
# Out:
# 0
# DISTRICT    NICOBAR
# Name: 0, dtype: object
# 1
# DISTRICT    SOUTH ANDAMAN
# Name: 1, dtype: object
# 2
# DISTRICT    N & M ANDAMAN
# Name: 2, dtype: object
# 3
# DISTRICT    LOHIT
# Name: 3, dtype: object
# 4
# DISTRICT    EAST SIANG
# Name: 4, dtype: object
# 5
# DISTRICT    SUBANSIRI F.D
# Name: 5, dtype: object
# 6
# DISTRICT    TIRAP
# Name: 6, dtype: object
# 7
# DISTRICT    ANJAW (LOHIT)
# Name: 7, dtype: object
# 8
# DISTRICT    LOWER DIBANG
# Name: 8, dtype: object
# 9
# DISTRICT    CHANGLANG
# Name: 9, dtype: object
# 10
# DISTRICT    PAPUM PARE
# Name: 10, dtype: object
# 11
# DISTRICT    LOW SUBANSIRI
# Name: 11, dtype: object
# 12
# DISTRICT    UPPER SIANG
# Name: 12, dtype: object
# 13
# DISTRICT    WEST SIANG
# Name: 13, dtype: object
# 14
# DISTRICT    DIBANG VALLEY
# Name: 14, dtype: object
# 15
# DISTRICT    WEST KAMENG
# Name: 15, dtype: object
# 16
# DISTRICT    EAST KAMENG
# Name: 16, dtype: object
# 17
# DISTRICT    TAWANG(W KAME
# Name: 17, dtype: object
# ...

# %%
dataset.loc[:, ['DISTRICT', 'JAN']].head()
# Out:
#         DISTRICT    JAN
# 0        NICOBAR  107.3
# 1  SOUTH ANDAMAN   43.7
# 2  N & M ANDAMAN   32.7
# 3          LOHIT   42.2
# 4     EAST SIANG   33.3

# %%
dataset[0:3]
# Out:
#                       STATE/UT       DISTRICT    JAN   FEB   MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9  65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0  18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9   8.6   53.4
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  JAN+FEB  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
#
#      MAM    JJAS    OND
# 0  540.7  1207.2  892.1
# 1  483.5  1757.2  705.3
# 2  405.6  1884.4  574.7

# %%
dataset.iloc[0:3,0:3]
# Out:
#                       STATE/UT       DISTRICT    JAN
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7

# %% [markdown]
# # Data Cleaning

# %%
dataset.isnull()
# Out:
#      STATE/UT  DISTRICT    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 0       False     False  False  False  False  False  False  False  False
# 1       False     False  False  False  False  False  False  False  False
# 2       False     False  False  False  False  False  False  False  False
# 3       False     False  False  False  False  False  False  False  False
# 4       False     False  False  False  False  False  False  False  False
# ..        ...       ...    ...    ...    ...    ...    ...    ...    ...
# 636     False     False  False  False  False  False  False  False  False
# 637     False     False  False  False  False  False  False  False  False
# 638     False     False  False  False  False  False  False  False  False
# 639     False     False  False  False  False  False  False  False  False
# 640     False     False  False  False  False  False  False  False  False
#
#        AUG    SEP    OCT    NOV    DEC  ANNUAL  JAN+FEB    MAM   JJAS    OND
# ...

# %%
dataset.isnull().sum()
# Out:
# STATE/UT    0
# DISTRICT    0
# JAN         0
# FEB         0
# MAR         0
# APR         0
# MAY         0
# JUN         0
# JUL         0
# AUG         0
# SEP         0
# OCT         0
# NOV         0
# DEC         0
# ANNUAL      0
# JAN+FEB     0
# MAM         0
# JJAS        0
# OND         0
# dtype: int64

# %%
# removed the null values if they below 5%, replace it with mean or median
dataset.dropna()
# Out:
#                         STATE/UT        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
# fillna()

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ax = dataset['JAN'].plot.hist()
ax.set_xlabel('Rainfall in Jan')
print(dataset['JAN'].min())
print(dataset['JAN'].max())
print(dataset['JAN'].mean())
# Out:
# 0.0
# 144.5
# 18.355070202808125
